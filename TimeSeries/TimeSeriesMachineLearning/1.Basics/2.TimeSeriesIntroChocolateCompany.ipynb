# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/0.Cloud Computing and Streaming Tech/OCI AI/0.GoogleColab/Python - Time Series Forecasting/Time Series Analysis/Introduction to Time Series Forecasting"
# Out:
# /content/drive/MyDrive/0.Cloud Computing and Streaming Tech/OCI AI/0.GoogleColab/Python - Time Series Forecasting/Time Series Analysis/Introduction to Time Series Forecasting

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import month_plot, quarter_plot, plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Import a the clocolate dataset
df_choco = pd.read_csv("choco_monthly_revenue.csv", index_col='Month with Year', parse_dates=True)
df_choco.head()
# Out:
#                  revenue
# Month with Year
# 2018-01-01          1458
# 2018-02-01          1102
# 2018-03-01          1584
# 2018-04-01          1676
# 2018-05-01          1461

# %%
# Plot the month_plot for df_choco
month_plot(df_choco['revenue'],
           ylabel = 'Revenue')

plt.show()

# %%
# Seasonality for df_choco
decomposition = seasonal_decompose(df_choco['revenue'],
                                   model = 'multiplicative',
                                   period=12)
fig = decomposition.plot()
fig.set_size_inches(18, 10)
plt.show()

# %%
# Preview the info of df_choco
df_choco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 60 entries, 2018-01-01 to 2022-12-01
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   revenue  60 non-null     int64
# dtypes: int64(1)
# memory usage: 960.0 bytes

# %%
# Plot teh ACF of the reveneue kpi in df_choco
fig, ax = plt.subplots(figsize = (12, 6))
plot_acf(df_choco['revenue'],
         lags = 20,
         ax = ax)
plt.show()

# %%
# PACF for teh revenue in df_choco
fig, ax = plt.subplots(figsize = (12, 6))
plot_pacf(df_choco['revenue'],
          lags = 20,
          ax = ax)
plt.show()
